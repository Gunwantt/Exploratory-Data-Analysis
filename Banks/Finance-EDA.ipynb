# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
data = pd.read_pickle('all_banks')

# %%
df = data.copy()

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2517 entries, 2006-01-03 to 2015-12-31
# Data columns (total 30 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   (BAC, Open)    2517 non-null   float64
#  1   (BAC, High)    2517 non-null   float64
#  2   (BAC, Low)     2517 non-null   float64
#  3   (BAC, Close)   2517 non-null   float64
#  4   (BAC, Volume)  2517 non-null   int64
#  5   (C, Open)      2517 non-null   float64
#  6   (C, High)      2517 non-null   float64
#  7   (C, Low)       2517 non-null   float64
#  8   (C, Close)     2517 non-null   float64
#  9   (C, Volume)    2517 non-null   int64
#  10  (GS, Open)     2517 non-null   float64
#  11  (GS, High)     2517 non-null   float64
#  12  (GS, Low)      2517 non-null   float64
#  13  (GS, Close)    2517 non-null   float64
#  14  (GS, Volume)   2517 non-null   int64
#  15  (JPM, Open)    2517 non-null   float64
#  16  (JPM, High)    2517 non-null   float64
# ...

# %%
df.describe()
# Out:
# Bank Ticker          BAC                                                       \
# Stock Info          Open         High          Low        Close        Volume
# count        2517.000000  2517.000000  2517.000000  2517.000000  2.517000e+03
# mean           22.205217    22.479182    21.894076    22.174617  1.333590e+08
# std            15.308041    15.406193    15.197964    15.304852  1.274974e+08
# min             3.220000     3.510000     2.530000     3.140000  4.836000e+06
# 25%            12.310000    12.450000    12.130000    12.270000  4.845598e+07
# 50%            15.780000    15.970000    15.600000    15.790000  1.015867e+08
# 75%            32.730000    33.600000    31.750000    32.630000  1.752694e+08
# max            55.040000    55.080000    54.820000    54.900000  1.226791e+09
#
# Bank Ticker            C                                                       \
# Stock Info          Open         High          Low        Close        Volume
# ...

# %% [markdown]
# # EDA

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
banks = ['BAC', 'C', 'GS', 'JPM', 'MS', 'WFC']

# %% [markdown]
# ### Max Close Price for each bank's Stock

# %%
df.xs(key='Close', axis=1, level='Stock Info').max()
# Out:
# Bank Ticker
# BAC     54.90
# C      564.10
# GS     247.92
# JPM     70.08
# MS      89.30
# WFC     58.52
# dtype: float64

# %% [markdown]
# ### Creating dataframe for returns on each banks stock

# %%
returns_df = pd.DataFrame()

# %%
for bank in banks:
    returns_df[bank + ' Return'] = df[bank]['Close'].pct_change()

# %%
returns_df.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %% [markdown]
# #### 1st row is null as there is nothing in the past to compare it to

# %%
sns.pairplot(returns_df)

# %% [markdown]
# City Group had huge crash back in 2008, Hence the returns of CityGroup are unlike other stocks

# %% [markdown]
# ### Checking the Best and Worst return date for each bank

# %%
returns_df.head()
# Out:
#             BAC Return  C Return  GS Return  JPM Return  MS Return  WFC Return
# Date
# 2006-01-03         NaN       NaN        NaN         NaN        NaN         NaN
# 2006-01-04   -0.010620 -0.018462  -0.013812   -0.014183   0.000686   -0.011599
# 2006-01-05    0.001288  0.004961  -0.000393    0.003029   0.002742   -0.000951
# 2006-01-06   -0.001501  0.000000   0.014169    0.007046   0.001025    0.005714
# 2006-01-09    0.000644 -0.004731   0.012030    0.016242   0.010586    0.000000

# %%
returns_df.idxmin()
# Out:
# BAC Return   2009-01-20
# C Return     2011-05-06
# GS Return    2009-01-20
# JPM Return   2009-01-20
# MS Return    2008-10-09
# WFC Return   2009-01-20
# dtype: datetime64[ns]

# %% [markdown]
# #### 4 of the banks share same date for worst drop

# %%
returns_df.idxmax()
# Out:
# BAC Return   2009-04-09
# C Return     2011-05-09
# GS Return    2008-11-24
# JPM Return   2009-01-21
# MS Return    2008-10-13
# WFC Return   2008-07-16
# dtype: datetime64[ns]

# %% [markdown]
# ### Checking which stock was the riskiest across entire period

# %%
returns_df.std().sort_values(ascending=False)
# Out:
# C Return      0.179969
# MS Return     0.037820
# BAC Return    0.036650
# WFC Return    0.030233
# JPM Return    0.027656
# GS Return     0.025346
# dtype: float64

# %% [markdown]
# C Returns was the riskiest of all because of very high standard deviation compared to other stocks

# %% [markdown]
# ### Checking fluctuations in the year 2015

# %%
returns_df.loc['2015-01-01':'2015-12-31',:].std().sort_values(ascending=False)
# Out:
# MS Return     0.016249
# BAC Return    0.016163
# C Return      0.015289
# GS Return     0.014046
# JPM Return    0.014017
# WFC Return    0.012591
# dtype: float64

# %%
sns.set_style('darkgrid')

# %%
sns.distplot(returns_df.loc['2015-01-01':'2015-12-31','MS Return'], bins=40)
# Out:
# C:\Users\Gunwant\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='MS Return', ylabel='Density'>

# %% [markdown]
# Returns on MS were very stable with deflection of about 0.06 only

# %%
sns.distplot(returns_df.loc['2008-01-01':'2008-12-31','C Return'], bins=40, color='g')
# Out:
# C:\Users\Gunwant\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='C Return', ylabel='Density'>

# %% [markdown]
# In this case, the deflection is very high which is 0.2

# %%
import plotly
import cufflinks as cf
cf.go_offline()
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.6.3.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
df.head()
# Out:
# Bank Ticker    BAC                                     C                       \
# Stock Info    Open   High    Low  Close    Volume   Open   High    Low  Close
# Date
# 2006-01-03   46.92  47.18  46.15  47.08  16296700  490.0  493.8  481.1  492.9
# 2006-01-04   47.00  47.24  46.45  46.58  17757900  488.6  491.0  483.5  483.8
# 2006-01-05   46.58  46.83  46.32  46.64  14970900  484.4  487.8  484.0  486.2
# 2006-01-06   46.80  46.91  46.35  46.57  12599800  488.8  489.0  482.0  486.2
# 2006-01-09   46.72  46.97  46.36  46.60  15620000  486.0  487.4  483.0  483.9
#
# Bank Ticker           ...     MS                                  WFC         \
# Stock Info    Volume  ...   Open   High    Low  Close   Volume   Open   High
# Date                  ...
# 2006-01-03   1537660  ...  57.17  58.49  56.74  58.31  5377000  31.60  31.98
# 2006-01-04   1871020  ...  58.70  59.28  58.35  58.35  7977800  31.80  31.82
# 2006-01-05   1143160  ...  58.55  58.59  58.02  58.51  5778000  31.50  31.56
# ...

# %%
close_corr = df.xs(key='Close', level='Stock Info', axis=1).corr()

# %%
plt.figure(figsize=(12,5))
for bank in banks:
    df[bank].Close.plot(label=bank)
plt.legend()

# %%
df.xs(level='Stock Info', key='Close', axis=1).iplot()
# Out:
# <div>                            <div id="7ce996f5-ee7d-4be7-9e96-dda15130429b" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};
# ...

# %% [markdown]
# We can see here, CityGroup just crashed in 2008 and Goldman sachs also crashed in 2008 but bounced back up very quickly

# %%
plt.figure(figsize=(7,6))
mask = np.triu(df.xs(key='Close', level='Stock Info', axis=1).corr())
sns.heatmap(close_corr, annot=True, cmap='coolwarm', mask=mask)
# Out:
# <AxesSubplot:xlabel='Bank Ticker', ylabel='Bank Ticker'>

# %%
sns.clustermap(close_corr, annot=True, cmap='coolwarm')
